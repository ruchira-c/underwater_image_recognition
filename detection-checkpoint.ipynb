# %% [markdown]
# ### Load Modules

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %% [markdown]
# ### Prepare/collect data

# %%
import os
path = os.listdir('datasets/Training/')
classes = {'Fish':0, 'Human':1}

# %%
import cv2
X = []
Y = []
for cls in classes:
    pth = 'datasets/Training/'+cls
    for j in os.listdir(pth):
        img = cv2.imread(pth+'/'+j, 0)
        img = cv2.resize(img, (200,200))
        X.append(img)
        Y.append(classes[cls])

# %%
X = np.array(X)
Y = np.array(Y)

# %%
np.unique(Y)
# Out:
# array([0, 1])

# %%
pd.Series(Y).value_counts()
# Out:
# 0    1951
# 1    1951
# dtype: int64

# %%
X.shape
# Out:
# (3902, 200, 200)

# %% [markdown]
# ### Visualize data

# %%
plt.imshow(X[0], cmap='gray')

# %% [markdown]
# ### Prepare data

# %%
X_updated = X.reshape(len(X), -1)
X_updated.shape
# Out:
# (3902, 40000)

# %% [markdown]
# ### Split Data

# %%
xtrain, xtest, ytrain, ytest = train_test_split(X_updated, Y, random_state=10,
                                               test_size=.20)

# %%
xtrain.shape, xtest.shape
# Out:
# ((3121, 40000), (781, 40000))

# %% [markdown]
# ### Feature Scaling

# %%
print(xtrain.max(), xtrain.min())
print(xtest.max(), xtest.min())
xtrain = xtrain/255
xtest = xtest/255
print(xtrain.max(), xtrain.min())
print(xtest.max(), xtest.min())
# Out:
# 255 0
# 255 0
# 1.0 0.0
# 1.0 0.0

# %% [markdown]
# ### Feature Selection: PCA

# %%
from sklearn.decomposition import PCA

# %%
print(xtrain.shape, xtest.shape)

pca = PCA(.98)
pca_train = xtrain
pca_test = xtest
# Out:
# (3121, 40000) (781, 40000)

# %% [markdown]
# ### Train Model

# %%
from sklearn.svm import SVC

# %%
sv = SVC()
sv.fit(pca_train, ytrain)
# Out:
# SVC()

# %% [markdown]
# ### Evaluation

# %%
print("Training Score:", sv.score(pca_train, ytrain))
print("Testing Score:", sv.score(pca_test, ytest))
# Out:
# Training Score: 0.9618711951297662
# Testing Score: 0.9372599231754162

# %% [markdown]
# ### Prediction

# %%
pred = sv.predict(pca_test)
np.where(ytest!=pred)
# Out:
# (array([ 39, 105, 111, 116, 139, 143, 173, 174, 208, 210, 256, 293, 308,
#         317, 318, 325, 335, 353, 363, 369, 378, 392, 398, 413, 425, 433,
#         457, 468, 517, 518, 524, 536, 537, 546, 572, 587, 590, 616, 619,
#         628, 654, 682, 714, 728, 733, 741, 760, 763, 766], dtype=int64),)

# %%
pred[36]
# Out:
# 0

# %%
ytest[36]
# Out:
# 0

# %% [markdown]
# # Confusion Matrix

# %%
conf_matrix=metrics.confusion_matrix(ytest,pred)
cm_display = metrics.ConfusionMatrixDisplay(confusion_matrix =conf_matrix , display_labels = [False, True])
cm_display.plot()
plt.show()

# %% [markdown]
# # Accuracy

# %%
accuracy=metrics.accuracy_score(ytest,pred)
print(accuracy)
# Out:
# 0.9372599231754162

# %% [markdown]
# ### TEST MODEL

# %%
dec = {0:'Fish', 1:'Human'}

# %%
plt.figure(figsize=(12,8))
p = os.listdir('datasets/Testing/')
c=1
for i in os.listdir('datasets/Testing/Fish/')[:9]:
    plt.subplot(3,3,c)
    
    img = cv2.imread('datasets/Testing/Fish/'+i,0)
    img1 = cv2.resize(img, (200,200))
    img1 = img1.reshape(1,-1)/255
    p = sv.predict(img1)
    plt.title(dec[p[0]])
    plt.imshow(img, cmap='gray')
    plt.axis('off')
    c+=1

# %%
plt.figure(figsize=(12,8))
p = os.listdir('datasets/Testing/')
c=1
for i in os.listdir('datasets/Testing/Human/')[:16]:
    plt.subplot(4,4,c)
    
    img = cv2.imread('datasets/Testing/Human/'+i,0)
    img1 = cv2.resize(img, (200,200))
    img1 = img1.reshape(1,-1)/255
    p = sv.predict(img1)
    plt.title(dec[p[0]])
    plt.imshow(img, cmap='gray')
    plt.axis('off')
    c+=1
